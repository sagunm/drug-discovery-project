# %% [markdown]
# <a href="https://colab.research.google.com/github/sagunm/drug-discovery-project/blob/main/Comparing_Regressors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Importing libraries**

# %%
! pip install lazypredict

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df['pIC50']

# %% [markdown]
# ### **Data pre-processing**

# %%
X.shape #getting the dimension of X
# Out:
# (4695, 881)

# %%
# Removing low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Performing data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ### **Comparing ML Algorithms**

# %%
# Defining and building the lazyclassifier
clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
train, test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:51<00:00,  1.22s/it]

# %%
# performance table of the training set (80% subset)
train
# Out:
#                                        Adjusted R-Squared  ...  Time Taken
# Model                                                      ...
# HistGradientBoostingRegressor                        0.42  ...        2.20
# LGBMRegressor                                        0.42  ...        0.41
# RandomForestRegressor                                0.42  ...        4.52
# BaggingRegressor                                     0.38  ...        0.53
# XGBRegressor                                         0.35  ...        1.88
# NuSVR                                                0.33  ...        3.50
# KNeighborsRegressor                                  0.33  ...        0.98
# SVR                                                  0.33  ...        4.28
# MLPRegressor                                         0.32  ...        6.76
# GradientBoostingRegressor                            0.27  ...        1.67
# ExtraTreesRegressor                                  0.18  ...        5.88
# ...

# %%
# performance table of the test set (20% subset)
test
# Out:
#                                        Adjusted R-Squared  ...  Time Taken
# Model                                                      ...
# HistGradientBoostingRegressor                        0.42  ...        2.20
# LGBMRegressor                                        0.42  ...        0.41
# RandomForestRegressor                                0.42  ...        4.52
# BaggingRegressor                                     0.38  ...        0.53
# XGBRegressor                                         0.35  ...        1.88
# NuSVR                                                0.33  ...        3.50
# KNeighborsRegressor                                  0.33  ...        0.98
# SVR                                                  0.33  ...        4.28
# MLPRegressor                                         0.32  ...        6.76
# GradientBoostingRegressor                            0.27  ...        1.67
# ExtraTreesRegressor                                  0.18  ...        5.88
# ...

# %% [markdown]
# ### **Data visualisation of model performance**

# %%
# bar plot r-squared values
# train['R-Squared'] = [0 if i < 0. else i for i in train.ioc[:,0]]

import matplotlib.pyplot as plt

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x='R-Squared', data=predictions_train)
ax.set(xlim=(0,1))
# Out:
# [(0.0, 1.0)]

# %%
# bar plot of RMSE values
plt.figure(figsize=(5,10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=predictions_train.index, x='RMSE', data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# bar plot of calculation time

plt.figure(figsize=(5,10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=predictions_train.index, x='Time Taken', data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
